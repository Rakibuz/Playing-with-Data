# %%
import pandas as pd
import csv

# %%
df = pd.read_csv("avrg_custom.csv")

# %%
df
# Out:
#     Year  Month   avg_tmin   avg_tmax   avg_tavg   avg_prcp
# 0   2000      1  11.877419  24.212903  17.364516   0.580645
# 1   2000      2  13.789655  25.120690  19.182759   0.689655
# 2   2000      3  18.593548  29.919355  23.774194   2.387097
# 3   2000      4  21.726667  31.096667  26.123333  10.600000
# 4   2000      5  24.029032  31.341935  26.970968  14.903226
# ..   ...    ...        ...        ...        ...        ...
# 62  2022      3  20.474194  32.038710  25.774194   0.000000
# 63  2022      4  24.140000  32.033333  28.036667   2.000000
# 64  2022      5  24.319355  31.893548  27.841935   9.806452
# 65  2022      6  25.753333  31.020000  27.850000  15.633333
# 66  2022      7  27.064516  33.216129  29.819355   3.806452
#
# [67 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

# %%
 df.plot(x="Month", y=["avg_tavg"])
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a pandas DataFrame
df = pd.read_csv("avrg_custom.csv")

# Create the figure and the two axes
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

# Plot the data on the two axes
ax1.plot(df['Month'], df['Year'], 'g-')
ax2.plot(df['Month'], df['avg_tavg'], 'b-')

# Set the labels for the x and y axes
ax1.set_xlabel('Month')
ax1.set_ylabel('Year', color='g')
ax2.set_ylabel('avg_tavg', color='b')

# Set the title for the plot
plt.title('Title of the plot')

# Show the plot
plt.show()

# %%
import numpy as np

# %%
a=np.loadtxt('2000.txt')
b=np.loadtxt('2005.txt')

# %%
x=a[:,1]
y=a[:,4]
plt.plot(x,y)

# %%
x2=b[:,1]
y2=b[:,4]
plt.plot(x,y)

# %%
x=a[:,1]
y=a[:,4]

x2=b[:,1]
y2=b[:,0]



fig, ax1 = plt.subplots()
ax1.set_xlabel('Month')
ax1.set_ylabel('avg_tavg')
ax1.plot(x,y,linewidth=2,color='red')



ax2=ax1.twinx()
ax2.set_ylabel('Y2')
ax1.plot(x2,y2,linewidth=2,color='blue')
fig.tight_layout()
plt.show()
